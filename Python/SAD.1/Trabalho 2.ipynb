# %% [markdown]
# # Bruna Grassi - 50012984

# %%
import pandas as pd # conventional alias
from sklearn.datasets import load_boston

dataset = load_boston()

# %% [markdown]
# ## 1 - Mostre os primeiros registros da tabela

# %%
data = pd.DataFrame(dataset.data, columns=dataset.feature_names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# ## 2- Observações(linhas) possui nessa base? Quantas Colunas?

# %%
data.shape
# Out:
# (506, 13)

# %% [markdown]
# ## 3- Quantas Features Possui?
# ### R: 13
# ## 4- Qual é o campo Target(respostas) dessa base?

# %%
data['target'] = dataset.target
print(data['target'])
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
# 5      28.7
# 6      22.9
# 7      27.1
# 8      16.5
# 9      18.9
# 10     15.0
# 11     18.9
# 12     21.7
# 13     20.4
# 14     18.2
# 15     19.9
# 16     23.1
# 17     17.5
# 18     20.2
# 19     18.2
# 20     13.6
# 21     19.6
# 22     15.2
# 23     14.5
# 24     15.6
# 25     13.9
# 26     16.6
# 27     14.8
# 28     18.4
# 29     21.0
#        ...
# 476    16.7
# 477    12.0
# 478    14.6
# 479    21.4
# 480    23.0
# 481    23.7
# 482    25.0
# 483    21.8
# 484    20.6
# 485    21.2
# 486    19.1
# 487    20.6
# 488    15.2
# 489     7.0
# 490     8.1
# 491    13.6
# 492    20.1
# 493    21.8
# 494    24.5
# 495    23.1
# 496    19.7
# 497    18.3
# 498    21.2
# 499    17.5
# 500    16.8
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: target, dtype: float64

# %% [markdown]
# ## 5- Usando a biblioteca de visualização seaborn, plote o gráfico que mostra a relação entre as features e responses

# %%
import seaborn as sns

# plot 
# %matplotlib inline

# %%
sns.pairplot(data, x_vars=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'], y_vars='target', size=7, aspect=0.7, kind='reg')

# %% [markdown]
# ## 6- Prepare X e y usando o pandas

# %%
# create a Python list of feature names
feature_cols = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

# use the list to select a subset of the original DataFrame
X = data[feature_cols]

# equivalent command to do this in one line
X = data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]

# print the first 5 rows
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
# selecionando a 'serie' do dataframe
y = data['target']

# funciona se nao tiver espaco no nome da coluna
y = data.target

y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: target, dtype: float64

# %% [markdown]
# ## 7- Qual o tipo de dados de X e y?

# %%
print(type(X))
print(X.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (506, 13)

# %%
print(type(y))
print(y.shape)
# Out:
# <class 'pandas.core.series.Series'>
# (506,)

# %% [markdown]
# ## 8- Sobre o que se trata essa base de dados? Que tipo de informações ela guarda?
# ### Trata-se de um conjunto de dados com informações coletadas pelo Serviço de Censo dos EUA sobre habitação na área da Boston Mass.

# %% [markdown]
# ## 9- Gere um X de treino e y de treino, X de teste e y da base (Split Train/Test)

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (379, 13)
# (379,)
# (127, 13)
# (127,)
# C:\Users\aluno.unilasalle\Downloads\WinPython-64bit-3.5.3.1Qt5\python-3.5.3.amd64\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ## 10- Qual o percentual gerado para criar o conjunto de treino e o conjunto de teste?
# ### train: 379*100/506 = 74,9
# ### test: 127/506 = 25,1
# ## 11- Usando modelo de regressão linear do sklearn, treine o modelo com o X e y de treino

# %%
from sklearn.linear_model import LinearRegression

linreg = LinearRegression()

linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ## 12- Imprima os atributos de "intercept" e "coefficients" que foram gerados

# %%
# y = ax + b pra descobrir a inclinação da linha
print(linreg.intercept_) # valor de b
print(linreg.coef_) # inclinação das mídias , valor de a
# Out:
# 45.2364158461
# [ -1.13256952e-01   5.70869807e-02   3.87621062e-02   2.43279795e+00
#   -2.12706290e+01   2.86930027e+00   7.02105327e-03  -1.47118312e+00
#    3.05187368e-01  -1.06649888e-02  -9.97404179e-01   6.39833822e-03
#   -5.58425480e-01]

# %% [markdown]
# ## 13- imprima o par "feature names" com os "coefficients"

# %%
list(zip(feature_cols, linreg.coef_))
# Out:
# [('CRIM', -0.11325695150325728),
#  ('ZN', 0.057086980673964144),
#  ('INDUS', 0.038762106170569355),
#  ('CHAS', 2.4327979454809934),
#  ('NOX', -21.27062900549695),
#  ('RM', 2.8693002671025591),
#  ('AGE', 0.0070210532717525087),
#  ('DIS', -1.4711831191291087),
#  ('RAD', 0.30518736758418985),
#  ('TAX', -0.010664988782810525),
#  ('PTRATIO', -0.99740417877290044),
#  ('B', 0.0063983382249377385),
#  ('LSTAT', -0.55842548000832615)]

# %% [markdown]
# ## 14- Faça uma previsão usando o conjunto de X de teste

# %%
# previsao
y_pred = linreg.predict(X_test)
print(y_pred)
# Out:
# [ 31.93969866  27.85335425  18.0115103   21.79927361  18.27742347
#   20.13833647  32.01672716  18.22113808  24.61193478  26.9040144
#   26.80834807  28.60517526  20.93229877  26.62779105  23.32844274
#   20.87786786  17.19770723  37.63912794  30.38390212   8.24030334
#   20.92618466  16.17445002  25.26391878  24.95964788  31.26789113
#   10.79485139  13.58275323  17.21120542  35.8490514   14.14390987
#   21.64225308  13.93242075  42.40744214  17.70509545  22.00388155
#   20.15370348  16.8192176   27.37502159  10.44406025  19.40935353
#   24.42051358  21.35942781  29.30679186  15.44940566  19.09892567
#   13.9836594   40.04836764  18.27140257  26.38052818  20.14965014
#   24.40613888  24.36470628  25.38317461  26.94583003   4.49805715
#   24.14537729   9.96767796  26.98795074  16.84799994  35.4444663
#   19.42286281  27.59708576  15.96831408  18.29906681  10.3002421
#   32.11063814  36.39545344  22.35538283  24.94918643  25.53449209
#   23.61130912   7.99319383  15.89431316  20.43256217  20.45675398
#   21.06341317  34.08101705  28.08242568  25.28683357  34.21996961
#   18.5850284   23.89020629  34.29105807  12.79838792  21.2464959
#   30.09351447  16.44720136  24.45714491  18.98076681  16.9534192
#   27.12806767  40.99174302  14.39085726  23.26067047  17.52000994
#   21.97730772  23.0201874   29.06960211  36.5869506   20.21467065
#   17.41364798  17.27407536  25.37171735  22.03069073   8.35322355
#   21.50592942  15.59553503  33.36057251  24.3259011   25.0863197
#   38.31786221  28.7724415   13.84057859  34.34324282  35.37156784
#   33.00112385  21.01239186  16.63124952  34.19148927  38.86887963
#   21.64176395  15.04467358  27.67069007  17.97023513  27.07160817
#   20.94893403  26.18594155]

# %% [markdown]
# ## 15- Mostre a margem de error, usando o método "Root Mean Squared Error (RMSE)"

# %%
from sklearn import metrics

# %%
import numpy as np

# RMSE
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 4.67860763823

# %% [markdown]
# ## 16- Existe uma forma de melhorar essa margem para que fique menor? Se sim, como seria?

# %%
feature_cols = ['ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

X = data[feature_cols]

y = data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

linreg.fit(X_train, y_train)

y_pred = linreg.predict(X_test)

print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 4.66790960147
